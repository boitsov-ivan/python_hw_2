# %% [markdown]
# # Репозиторий

# %% [markdown]
# https://github.com/boitsov-ivan/python_hw_2

# %% [markdown]
# # Подтверждение успешного деплоя

# %%
# Пример подтверждения успешного деплоя
from IPython.display import Image, display
display(Image(filename='aiogram_bot/docker_1.png'))

# %%
display(Image(filename='aiogram_bot/docker_2.png'))

# %%
display(Image(filename='aiogram_bot/docker_3.png'))

# %%
display(Image(filename='aiogram_bot/docker_4.png'))

# %% [markdown]
# # Пример логов после деплоя

# %%
display(Image(filename='aiogram_bot/docker_logs.png'))

# %% [markdown]
# # Демонcтрация работы бота в telegram

# %% [markdown]
# @HSE_Python_HW2_bot

# %%
display(Image(filename='aiogram_bot/bot_start.png'))

# %%
display(Image(filename='aiogram_bot/set_profile.png'))

# %%
display(Image(filename='aiogram_bot/log_water.png'))

# %%
display(Image(filename='aiogram_bot/log_food.png'))

# %%
display(Image(filename='aiogram_bot/log_workout.png'))

# %%
display(Image(filename='aiogram_bot/check_progress.png'))
